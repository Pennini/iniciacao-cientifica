# %%
import torch
import pandas as pd
import numpy as np
import warnings

warnings.filterwarnings("ignore")

import sys
from pathlib import Path

# Adiciona pasta src ao path para imports
sys.path.insert(0, str(Path.cwd().parent / "src"))

from models.har import HarModel

har = HarModel()

# %%
har.main(verbose=True)

print("\n" + "="*60)
print("INFORMAÇÕES DO MODELO HAR")
print("="*60)
print(f"Samples de treino: {len(har.X_train)}")
print(f"Samples de teste: {len(har.X_test)}")
print(f"Total de samples: {len(har.X_train) + len(har.X_test)}")
# Out:
# === AVALIAÇÃO FINAL - LinearRegression (HAR) ===
# TREINO:
#   MSE: 1.558664e-05
#   MAE: 1.134825e-03
#   RMSE: 3.947992e-03
#   MAPE:  1.219232e+02
#
# TESTE:
#   MSE: 1.190542e-05
#   MAE: 1.076152e-03
#   RMSE: 3.450423e-03
#   MAPE:  1.352127e+02
# ...
#
# Visualizando previsões no conjunto de teste...
# Previsões salvas em: C:\Users\Lenovo\Documents\GitHub\iniciacao-cientifica\data\processed\har_predictions.csv
# Métricas salvas em: C:\Users\Lenovo\Documents\GitHub\iniciacao-cientifica\data\processed\har_metrics.csv
#
# ...
# INFORMAÇÕES DO MODELO HAR
# ...
# Samples de treino: 1790
# Samples de teste: 768
# Total de samples: 2558
